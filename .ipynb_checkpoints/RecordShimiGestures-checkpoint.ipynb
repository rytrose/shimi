# %% [markdown]
# # Recording a Gesture for Shimi
#
# First, run the cell below to instatiate the shimi object. It should move to its initial positions and then relax.

# %%
# Import some matplolib shortcuts for Jupyter notebook
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from shimi import *
from motion.move import *
from config.definitions import *
from motion.recorder import *
from motion.playback import *
from audio.audio import *
from audio.play_song_demo import *
from posenet.posenet import *

import time
import datetime

from copy import deepcopy

import os

import threading

# Load Shimi
shimi = Shimi(silent=False)

local_gestures = {}
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Connecting on /dev/ttyACM0
# Found motors with the following IDs: [1, 2, 3, 4, 5]

# %% [markdown]
# The cell below defines the recorder object. The first parameter is a reference to the motor controller, the second is a **list** of motor ids, referenced by a convenience property on `shimi`. The options are as follows:
# * `shimi.torso`
# * `shimi.neck_lr`
# * `shimi.neck_ud`
# * `shimi.phone`
# * `shimi.foot`
# * `shimi.all_motors`: this **returns a list**, so you don't need to wrap it in one in this call
#
#
# The final parameter is the duration for which you want to record.

# %%
r = Recorder(shimi, shimi.all_motors, 5.0)

# %% [markdown]
# This starts a recording. It will count down from 3 to let you know when the recording starts, then move Shimi as you want it to move. **The first thing this call does is relax the motors, so be sure it doesn't collapse on itself when you call this.**

# %%
r.record()
r.plot(plt.axes())

# %% [markdown]
# Then, run this to play back the recorded gesture.

# %%
r.play(plt.axes())

# %%
r.plot(plt.axes())

# %%
r.trim(0.4, end="front")

# %% [markdown]
# ### Here are some helper functions.

# %%
# Puts shimi in a neutral position with motors non-compliant
shimi.initial_position()

# %% [markdown]
# ## **Make sure Shimi will not collapse before you run this!!!**

# %%
# Makes the motors compliant
shimi.disable_torque()

# %% [markdown]
# ### Here's a hard-coded demo of Shimi dancing to Hey Ya

# %%
play_outkast(shimi)

# %%
play_opera(shimi)

# %%
from pprint import pprint
def on_prediction(pose):
    pprint(pose)

# %%
p = PoseNet(shimi, on_prediction=on_prediction)
# Out:
# Listening for OSC at 127.0.0.1 on port 8000
# Starting PoseNet...
# Receiving from PoseNet...
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '-11.716188430786133',
#                              'y': '303.73289012908936'},
#                 'score': '0.001440672'},
#                {'part': 'leftEye',
#                 'position': {'x': '-6.407748699188232',
#                              'y': '285.87074422836304'},
#                 'score': '0.0017271758'},
#                {'part': 'rightEye',
#                 'position': {'x': '-5.287797451019287',
#                              'y': '304.0376237779856'},
#                 'score': '0.0013545597'},
#                {'part': 'leftEar',
#                 'position': {'x': '-3.7096915245056152',
#                              'y': '108.41413497924805'},
#                 'score': '0.00088917214'},
#                {'part': 'rightEar',
#                 'position': {'x': '99.73233771324158',
#                              'y': '113.44196891784668'},
#                 'score': '0.0010161463'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '4.069960594177246',
#                              'y': '29.382895469665527'},
#                 'score': '0.001879123'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '-4.581490993499756',
#                              'y': '25.430962085723877'},
#                 'score': '0.0034493017'},
#                {'part': 'leftElbow',
#                 'position': {'x': '471.70482444763184',
#                              'y': '464.0241534523666'},
#                 'score': '0.0036843647'},
#                {'part': 'rightElbow',
#                 'position': {'x': '363.335702419281', 'y': '426.0490460395813'},
#                 'score': '0.0032303943'},
#                {'part': 'leftWrist',
#                 'position': {'x': '454.9039058685303',
#                              'y': '498.5279414653778'},
#                 'score': '0.0036761381'},
#                {'part': 'rightWrist',
#                 'position': {'x': '252.45000386238098',
#                              'y': '496.747290790081'},
#                 'score': '0.0045074685'},
#                {'part': 'leftHip',
#                 'position': {'x': '351.7486200928688',
#                              'y': '509.6120264530182'},
#                 'score': '0.014271244'},
#                {'part': 'rightHip',
#                 'position': {'x': '254.17086815834045',
#                              'y': '497.6813259124756'},
#                 'score': '0.012856109'},
#                {'part': 'leftKnee',
#                 'position': {'x': '351.1842409968376', 'y': '518.125289440155'},
#                 'score': '0.009241675'},
#                {'part': 'rightKnee',
#                 'position': {'x': '335.51274794340134',
#                              'y': '515.7985520362854'},
#                 'score': '0.008837346'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '302.5800518989563',
#                              'y': '513.1088293790817'},
#                 'score': '0.0046517327'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '333.2104113101959',
#                              'y': '513.3083779811859'},
#                 'score': '0.0053604175'}],
#  'score': '0.0048278259448981025'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '39.67026710510254',
#                              'y': '295.6894145011902'},
#                 'score': '0.9964798'},
#                {'part': 'leftEye',
#                 'position': {'x': '218.54592514038086',
#                              'y': '312.91086196899414'},
#                 'score': '0.99761426'},
#                {'part': 'rightEye',
#                 'position': {'x': '173.132253408432',
#                              'y': '313.47993087768555'},
#                 'score': '0.999342'},
#                {'part': 'leftEar',
#                 'position': {'x': '247.43430995941162',
#                              'y': '319.10716331005096'},
#                 'score': '0.86205596'},
#                {'part': 'rightEar',
#                 'position': {'x': '24.245600700378418',
#                              'y': '291.3111295700073'},
#                 'score': '0.9772813'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.67373466491699',
#                              'y': '304.9956597685814'},
#                 'score': '0.9956268'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.18286207318306',
#                              'y': '318.63593900203705'},
#                 'score': '0.9978992'},
#                {'part': 'leftElbow',
#                 'position': {'x': '66.04806804656982',
#                              'y': '330.4986181259155'},
#                 'score': '0.99229324'},
#                {'part': 'rightElbow',
#                 'position': {'x': '26.832761764526367',
#                              'y': '348.61435747146606'},
#                 'score': '0.9909685'},
#                {'part': 'leftWrist',
#                 'position': {'x': '66.95592331886292',
#                              'y': '343.57915782928467'},
#                 'score': '0.93495053'},
#                {'part': 'rightWrist',
#                 'position': {'x': '55.027164459228516',
#                              'y': '353.02191174030304'},
#                 'score': '0.8728324'},
#                {'part': 'leftHip',
#                 'position': {'x': '59.342002868652344',
#                              'y': '355.6501200199127'},
#                 'score': '0.95751053'},
#                {'part': 'rightHip',
#                 'position': {'x': '31.367321252822876',
#                              'y': '360.9463677406311'},
#                 'score': '0.985446'},
#                {'part': 'leftKnee',
#                 'position': {'x': '66.20723271369934',
#                              'y': '387.01566982269287'},
#                 'score': '0.7639071'},
#                {'part': 'rightKnee',
#                 'position': {'x': '46.20697247982025',
#                              'y': '387.81217336654663'},
#                 'score': '0.8430024'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '50.10471153259277',
#                              'y': '443.1957278251648'},
#                 'score': '0.57642096'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '44.04135870933533',
#                              'y': '442.5555863380432'},
#                 'score': '0.70452696'}],
#  'score': '0.9087151709724876'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '41.679232597351074',
#                              'y': '295.95609188079834'},
#                 'score': '0.99858487'},
#                {'part': 'leftEye',
#                 'position': {'x': '217.78806447982788',
#                              'y': '312.3383831977844'},
#                 'score': '0.9973586'},
#                {'part': 'rightEye',
#                 'position': {'x': '171.88197231292725',
#                              'y': '313.188364982605'},
#                 'score': '0.9991037'},
#                {'part': 'leftEar',
#                 'position': {'x': '248.03238725662231',
#                              'y': '316.97791051864624'},
#                 'score': '0.9799344'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.504199028015137',
#                              'y': '292.2878680229187'},
#                 'score': '0.9840888'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.50602674484253',
#                              'y': '306.12137818336487'},
#                 'score': '0.9975012'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.636692941188812',
#                              'y': '317.54051971435547'},
#                 'score': '0.9988487'},
#                {'part': 'leftElbow',
#                 'position': {'x': '69.72888803482056',
#                              'y': '326.0430474281311'},
#                 'score': '0.98951703'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.04134464263916',
#                              'y': '351.4777243733406'},
#                 'score': '0.9925196'},
#                {'part': 'leftWrist',
#                 'position': {'x': '66.37399387359619',
#                              'y': '344.07705211639404'},
#                 'score': '0.9627762'},
#                {'part': 'rightWrist',
#                 'position': {'x': '52.3135986328125', 'y': '351.5651015639305'},
#                 'score': '0.9263875'},
#                {'part': 'leftHip',
#                 'position': {'x': '59.267571449279785',
#                              'y': '356.1481828689575'},
#                 'score': '0.9482354'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.823797702789307',
#                              'y': '360.683798789978'},
#                 'score': '0.9852304'},
#                {'part': 'leftKnee',
#                 'position': {'x': '62.48190212249756',
#                              'y': '381.2058367729187'},
#                 'score': '0.7599917'},
#                {'part': 'rightKnee',
#                 'position': {'x': '42.922322273254395',
#                              'y': '379.1966061592102'},
#                 'score': '0.90424883'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '45.31448268890381',
#                              'y': '441.36250400543213'},
#                 'score': '0.74546283'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '44.81540870666504',
#                              'y': '440.71924591064453'},
#                 'score': '0.72129'}],
#  'score': '0.9347693955197054'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.96874713897705',
#                              'y': '295.4532961845398'},
#                 'score': '0.99827397'},
#                {'part': 'leftEye',
#                 'position': {'x': '218.1499514579773',
#                              'y': '312.7047276496887'},
#                 'score': '0.9974227'},
#                {'part': 'rightEye',
#                 'position': {'x': '171.4703631401062',
#                              'y': '312.92303371429443'},
#                 'score': '0.9992016'},
#                {'part': 'leftEar',
#                 'position': {'x': '247.64725589752197',
#                              'y': '316.8755147457123'},
#                 'score': '0.983988'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.977131366729736',
#                              'y': '292.3692202568054'},
#                 'score': '0.97909904'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.92075729370117',
#                              'y': '305.5788757801056'},
#                 'score': '0.99788445'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.931036472320557',
#                              'y': '317.9508697986603'},
#                 'score': '0.9987172'},
#                {'part': 'leftElbow',
#                 'position': {'x': '69.79599475860596',
#                              'y': '325.99772596359253'},
#                 'score': '0.98732066'},
#                {'part': 'rightElbow',
#                 'position': {'x': '24.349424362182617',
#                              'y': '350.8643329143524'},
#                 'score': '0.99088496'},
#                {'part': 'leftWrist',
#                 'position': {'x': '66.60661244392395',
#                              'y': '342.0515432357788'},
#                 'score': '0.95605224'},
#                {'part': 'rightWrist',
#                 'position': {'x': '51.038129806518555',
#                              'y': '354.5545048713684'},
#                 'score': '0.9219348'},
#                {'part': 'leftHip',
#                 'position': {'x': '54.88303279876709',
#                              'y': '357.8186082839966'},
#                 'score': '0.96207047'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.983988523483276',
#                              'y': '361.4956479072571'},
#                 'score': '0.9832144'},
#                {'part': 'leftKnee',
#                 'position': {'x': '66.55265998840332', 'y': '377.665087223053'},
#                 'score': '0.6739362'},
#                {'part': 'rightKnee',
#                 'position': {'x': '44.83115267753601',
#                              'y': '375.0992126464844'},
#                 'score': '0.8356374'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '43.61149978637695',
#                              'y': '441.1641454696655'},
#                 'score': '0.67114526'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '43.65697765350342',
#                              'y': '440.38502311706543'},
#                 'score': '0.677139'}],
#  'score': '0.9184660140205833'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '41.70754671096802', 'y': '295.876501083374'},
#                 'score': '0.99835783'},
#                {'part': 'leftEye',
#                 'position': {'x': '218.01539993286133',
#                              'y': '312.69391441345215'},
#                 'score': '0.9974591'},
#                {'part': 'rightEye',
#                 'position': {'x': '171.45892000198364',
#                              'y': '312.75145626068115'},
#                 'score': '0.999238'},
#                {'part': 'leftEar',
#                 'position': {'x': '247.37588500976562',
#                              'y': '316.65069460868835'},
#                 'score': '0.9819896'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.814189910888672',
#                              'y': '292.7401056289673'},
#                 'score': '0.9792473'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.27822780609131',
#                              'y': '306.05661273002625'},
#                 'score': '0.99757236'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '17.184197187423706',
#                              'y': '318.1021354198456'},
#                 'score': '0.9987324'},
#                {'part': 'leftElbow',
#                 'position': {'x': '66.55922508239746',
#                              'y': '325.99104261398315'},
#                 'score': '0.98543525'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.144187927246094',
#                              'y': '350.51110208034515'},
#                 'score': '0.9904484'},
#                {'part': 'leftWrist',
#                 'position': {'x': '65.6287876367569',
#                              'y': '342.14155673980713'},
#                 'score': '0.9559168'},
#                {'part': 'rightWrist',
#                 'position': {'x': '51.18416213989258',
#                              'y': '354.8842372894287'},
#                 'score': '0.9320144'},
#                {'part': 'leftHip',
#                 'position': {'x': '54.52572250366211',
#                              'y': '357.9948148727417'},
#                 'score': '0.9531741'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.041687488555908',
#                              'y': '361.6624674797058'},
#                 'score': '0.98091966'},
#                {'part': 'leftKnee',
#                 'position': {'x': '67.25566697120667',
#                              'y': '375.19186210632324'},
#                 'score': '0.63642544'},
#                {'part': 'rightKnee',
#                 'position': {'x': '45.16482067108154',
#                              'y': '372.6821823120117'},
#                 'score': '0.83333886'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '43.26142406463623', 'y': '440.894624710083'},
#                 'score': '0.6810202'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '43.15062999725342',
#                              'y': '440.0152778625488'},
#                 'score': '0.675064'}],
#  'score': '0.9162561051985797'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.71432113647461',
#                              'y': '295.25760555267334'},
#                 'score': '0.99835557'},
#                {'part': 'leftEye',
#                 'position': {'x': '212.87802743911743',
#                              'y': '310.19537448883057'},
#                 'score': '0.9968284'},
#                {'part': 'rightEye',
#                 'position': {'x': '166.65767669677734',
#                              'y': '313.97502088546753'},
#                 'score': '0.99896765'},
#                {'part': 'leftEar',
#                 'position': {'x': '243.23088812828064',
#                              'y': '314.6036968231201'},
#                 'score': '0.98049074'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.33191156387329',
#                              'y': '291.78385186195374'},
#                 'score': '0.9794669'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.698516845703125',
#                              'y': '305.1767302751541'},
#                 'score': '0.9978667'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.566041588783264',
#                              'y': '316.9473783969879'},
#                 'score': '0.9986552'},
#                {'part': 'leftElbow',
#                 'position': {'x': '70.04384851455688',
#                              'y': '323.2847349643707'},
#                 'score': '0.98772615'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.472905158996582',
#                              'y': '350.9187500476837'},
#                 'score': '0.9929066'},
#                {'part': 'leftWrist',
#                 'position': {'x': '68.11595916748047',
#                              'y': '340.4273591041565'},
#                 'score': '0.96962255'},
#                {'part': 'rightWrist',
#                 'position': {'x': '53.924203872680664',
#                              'y': '351.6317217350006'},
#                 'score': '0.9139361'},
#                {'part': 'leftHip',
#                 'position': {'x': '54.30319404602051',
#                              'y': '356.84689140319824'},
#                 'score': '0.96253467'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.953664779663086',
#                              'y': '360.9330487251282'},
#                 'score': '0.9857663'},
#                {'part': 'leftKnee',
#                 'position': {'x': '63.77606292068958',
#                              'y': '379.3565092086792'},
#                 'score': '0.70675045'},
#                {'part': 'rightKnee',
#                 'position': {'x': '43.7595534324646', 'y': '377.2502670288086'},
#                 'score': '0.8830901'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '44.90419864654541',
#                              'y': '441.6861934661865'},
#                 'score': '0.7363533'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '41.246474266052246',
#                              'y': '444.1531627178192'},
#                 'score': '0.72563946'}],
#  'score': '0.9302915720378652'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.412456035614014',
#                              'y': '295.1635675430298'},
#                 'score': '0.9985305'},
#                {'part': 'leftEye',
#                 'position': {'x': '212.97305011749268',
#                              'y': '315.203248500824'},
#                 'score': '0.99758923'},
#                {'part': 'rightEye',
#                 'position': {'x': '167.13066244125366',
#                              'y': '317.62577962875366'},
#                 'score': '0.99934953'},
#                {'part': 'leftEar',
#                 'position': {'x': '243.30006885528564',
#                              'y': '317.14870595932007'},
#                 'score': '0.98412365'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.1885085105896', 'y': '291.9604711532593'},
#                 'score': '0.97875094'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.138386249542236',
#                              'y': '306.1861882209778'},
#                 'score': '0.9976337'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.69631850719452',
#                              'y': '317.03418803215027'},
#                 'score': '0.9986964'},
#                {'part': 'leftElbow',
#                 'position': {'x': '69.6539363861084',
#                              'y': '324.12852334976196'},
#                 'score': '0.9844151'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.331867218017578',
#                              'y': '350.8570486307144'},
#                 'score': '0.9933428'},
#                {'part': 'leftWrist',
#                 'position': {'x': '67.98617672920227',
#                              'y': '341.14205980300903'},
#                 'score': '0.96993273'},
#                {'part': 'rightWrist',
#                 'position': {'x': '54.539124965667725',
#                              'y': '351.5799772441387'},
#                 'score': '0.92370486'},
#                {'part': 'leftHip',
#                 'position': {'x': '54.78872013092041',
#                              'y': '356.55656147003174'},
#                 'score': '0.96702874'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.419689893722534',
#                              'y': '360.9204716682434'},
#                 'score': '0.986034'},
#                {'part': 'leftKnee',
#                 'position': {'x': '62.40843904018402',
#                              'y': '379.51074981689453'},
#                 'score': '0.73205054'},
#                {'part': 'rightKnee',
#                 'position': {'x': '43.80066728591919',
#                              'y': '377.9227695465088'},
#                 'score': '0.8952688'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '44.60276985168457', 'y': '442.082706451416'},
#                 'score': '0.7130775'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '40.40565013885498',
#                              'y': '444.4263596534729'},
#                 'score': '0.7266753'}],
#  'score': '0.9321296635796043'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.603588581085205',
#                              'y': '295.43207693099976'},
#                 'score': '0.99840933'},
#                {'part': 'leftEye',
#                 'position': {'x': '213.401593208313',
#                              'y': '317.80085825920105'},
#                 'score': '0.9979158'},
#                {'part': 'rightEye',
#                 'position': {'x': '168.61884880065918',
#                              'y': '321.3868123292923'},
#                 'score': '0.999385'},
#                {'part': 'leftEar',
#                 'position': {'x': '243.67363142967224',
#                              'y': '316.22807812690735'},
#                 'score': '0.9866325'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.55067014694214',
#                              'y': '292.01653957366943'},
#                 'score': '0.9793698'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.78449821472168',
#                              'y': '305.48414289951324'},
#                 'score': '0.99790823'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.847197234630585',
#                              'y': '316.8359408378601'},
#                 'score': '0.99866164'},
#                {'part': 'leftElbow',
#                 'position': {'x': '69.8558874130249', 'y': '324.9343008995056'},
#                 'score': '0.9850419'},
#                {'part': 'rightElbow',
#                 'position': {'x': '24.944891929626465',
#                              'y': '350.2234857082367'},
#                 'score': '0.99244976'},
#                {'part': 'leftWrist',
#                 'position': {'x': '68.11440849304199',
#                              'y': '342.1027183532715'},
#                 'score': '0.9617142'},
#                {'part': 'rightWrist',
#                 'position': {'x': '53.66270589828491',
#                              'y': '351.94682067260146'},
#                 'score': '0.926051'},
#                {'part': 'leftHip',
#                 'position': {'x': '54.474700927734375',
#                              'y': '356.69482707977295'},
#                 'score': '0.9652195'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.05733609199524',
#                              'y': '360.72630071640015'},
#                 'score': '0.9852594'},
#                {'part': 'leftKnee',
#                 'position': {'x': '63.26665955781937',
#                              'y': '379.0704393386841'},
#                 'score': '0.72683525'},
#                {'part': 'rightKnee',
#                 'position': {'x': '43.613590717315674',
#                              'y': '376.63075590133667'},
#                 'score': '0.8962102'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '44.29805850982666', 'y': '441.907262802124'},
#                 'score': '0.7155843'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '44.64852809906006',
#                              'y': '441.17451667785645'},
#                 'score': '0.7265673'}],
#  'score': '0.9317185422953438'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.40543031692505',
#                              'y': '295.2689323425293'},
#                 'score': '0.99796'},
#                {'part': 'leftEye',
#                 'position': {'x': '157.79257154464722',
#                              'y': '344.9753475189209'},
#                 'score': '0.9959875'},
#                {'part': 'rightEye',
#                 'position': {'x': '109.92591118812561',
#                              'y': '354.3039402961731'},
#                 'score': '0.99952304'},
#                {'part': 'leftEar',
#                 'position': {'x': '199.05681085586548',
#                              'y': '332.9799704551697'},
#                 'score': '0.9650956'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.27037286758423',
#                              'y': '292.5128631591797'},
#                 'score': '0.98043746'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.524364948272705',
#                              'y': '307.44114780426025'},
#                 'score': '0.99713707'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '223.22410666942596',
#                              'y': '305.8601813316345'},
#                 'score': '0.9991353'},
#                {'part': 'leftElbow',
#                 'position': {'x': '70.208176612854', 'y': '327.0073127746582'},
#                 'score': '0.98107725'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.16068744659424',
#                              'y': '350.0259530544281'},
#                 'score': '0.99209607'},
#                {'part': 'leftWrist',
#                 'position': {'x': '66.56356596946716',
#                              'y': '343.0405673980713'},
#                 'score': '0.94990486'},
#                {'part': 'rightWrist',
#                 'position': {'x': '254.33280897140503',
#                              'y': '337.8000329732895'},
#                 'score': '0.96029216'},
#                {'part': 'leftHip',
#                 'position': {'x': '55.69097709655762', 'y': '356.496244430542'},
#                 'score': '0.97279274'},
#                {'part': 'rightHip',
#                 'position': {'x': '30.763055086135864',
#                              'y': '359.7605514526367'},
#                 'score': '0.9881821'},
#                {'part': 'leftKnee',
#                 'position': {'x': '63.83976484835148',
#                              'y': '378.4815649986267'},
#                 'score': '0.7565353'},
#                {'part': 'rightKnee',
#                 'position': {'x': '42.75011587142944',
#                              'y': '378.7970733642578'},
#                 'score': '0.8765272'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '45.02193260192871',
#                              'y': '442.5582580566406'},
#                 'score': '0.70306027'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '41.52350330352783',
#                              'y': '444.39658999443054'},
#                 'score': '0.7559651'}],
#  'score': '0.9336299405378454'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.4518256187439', 'y': '294.988929271698'},
#                 'score': '0.99818796'},
#                {'part': 'leftEye',
#                 'position': {'x': '164.33668422698975',
#                              'y': '351.15076065063477'},
#                 'score': '0.99849236'},
#                {'part': 'rightEye',
#                 'position': {'x': '113.00979566574097',
#                              'y': '356.562255859375'},
#                 'score': '0.99933726'},
#                {'part': 'leftEar',
#                 'position': {'x': '201.69865894317627',
#                              'y': '333.6023061275482'},
#                 'score': '0.9622085'},
#                {'part': 'rightEar',
#                 'position': {'x': '22.76924228668213',
#                              'y': '292.3363084793091'},
#                 'score': '0.9808015'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.65324115753174',
#                              'y': '307.36881589889526'},
#                 'score': '0.99760324'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '222.83258044719696',
#                              'y': '305.7749123573303'},
#                 'score': '0.9992267'},
#                {'part': 'leftElbow',
#                 'position': {'x': '71.78977727890015',
#                              'y': '325.7812166213989'},
#                 'score': '0.9684923'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.299769401550293',
#                              'y': '350.8436918258667'},
#                 'score': '0.9915758'},
#                {'part': 'leftWrist',
#                 'position': {'x': '67.98762011528015',
#                              'y': '341.2028441429138'},
#                 'score': '0.96304727'},
#                {'part': 'rightWrist',
#                 'position': {'x': '252.9798777103424',
#                              'y': '336.8781923055649'},
#                 'score': '0.9435691'},
#                {'part': 'leftHip',
#                 'position': {'x': '56.061901569366455',
#                              'y': '356.5142021179199'},
#                 'score': '0.96721566'},
#                {'part': 'rightHip',
#                 'position': {'x': '30.33677577972412',
#                              'y': '360.0884575843811'},
#                 'score': '0.98948264'},
#                {'part': 'leftKnee',
#                 'position': {'x': '62.54334783554077',
#                              'y': '380.52486753463745'},
#                 'score': '0.78229845'},
#                {'part': 'rightKnee',
#                 'position': {'x': '42.13080883026123',
#                              'y': '379.47447299957275'},
#                 'score': '0.89421934'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '45.23524856567383',
#                              'y': '442.03142738342285'},
#                 'score': '0.7299991'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '40.93599319458008',
#                              'y': '444.0838589668274'},
#                 'score': '0.78451693'}],
#  'score': '0.938251421732061'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.71622562408447',
#                              'y': '295.2276191711426'},
#                 'score': '0.99823666'},
#                {'part': 'leftEye',
#                 'position': {'x': '174.10684525966644',
#                              'y': '348.30251598358154'},
#                 'score': '0.9966415'},
#                {'part': 'rightEye',
#                 'position': {'x': '126.25035035610199',
#                              'y': '354.65953183174133'},
#                 'score': '0.99956053'},
#                {'part': 'leftEar',
#                 'position': {'x': '210.1598572731018', 'y': '343.494589805603'},
#                 'score': '0.8954093'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.575337409973145',
#                              'y': '292.1512141227722'},
#                 'score': '0.97672564'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.05808687210083',
#                              'y': '305.88981306552887'},
#                 'score': '0.9977114'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '222.34801399707794',
#                              'y': '304.94565212726593'},
#                 'score': '0.99926263'},
#                {'part': 'leftElbow',
#                 'position': {'x': '70.4986343383789', 'y': '325.4643135070801'},
#                 'score': '0.9835073'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.793971061706543',
#                              'y': '350.03049063682556'},
#                 'score': '0.9918509'},
#                {'part': 'leftWrist',
#                 'position': {'x': '67.19269847869873',
#                              'y': '342.72890043258667'},
#                 'score': '0.97271293'},
#                {'part': 'rightWrist',
#                 'position': {'x': '51.06459999084473',
#                              'y': '354.9317934513092'},
#                 'score': '0.89408493'},
#                {'part': 'leftHip',
#                 'position': {'x': '54.64003276824951',
#                              'y': '354.2050280570984'},
#                 'score': '0.96301156'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.775743007659912',
#                              'y': '359.0729122161865'},
#                 'score': '0.98626596'},
#                {'part': 'leftKnee',
#                 'position': {'x': '60.46464133262634',
#                              'y': '376.7413430213928'},
#                 'score': '0.7221101'},
#                {'part': 'rightKnee',
#                 'position': {'x': '42.46346139907837',
#                              'y': '377.8938455581665'},
#                 'score': '0.88865143'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '44.49810028076172',
#                              'y': '441.37392711639404'},
#                 'score': '0.7058087'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '40.936583042144775',
#                              'y': '442.7195224761963'},
#                 'score': '0.714044'}],
#  'score': '0.9226820854579701'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.609694957733154',
#                              'y': '295.03338718414307'},
#                 'score': '0.9984308'},
#                {'part': 'leftEye',
#                 'position': {'x': '174.92129707336426',
#                              'y': '348.3597240447998'},
#                 'score': '0.99672073'},
#                {'part': 'rightEye',
#                 'position': {'x': '126.20419549942017',
#                              'y': '354.6956584453583'},
#                 'score': '0.9996092'},
#                {'part': 'leftEar',
#                 'position': {'x': '208.77149105072021',
#                              'y': '342.67031955718994'},
#                 'score': '0.87741065'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.421457290649414',
#                              'y': '292.31922721862793'},
#                 'score': '0.9761421'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.87527084350586',
#                              'y': '305.8061102628708'},
#                 'score': '0.9977852'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '222.41492128372192',
#                              'y': '304.3369420468807'},
#                 'score': '0.9992793'},
#                {'part': 'leftElbow',
#                 'position': {'x': '70.49105787277222',
#                              'y': '326.7204399108887'},
#                 'score': '0.983824'},
#                {'part': 'rightElbow',
#                 'position': {'x': '24.732199668884277',
#                              'y': '349.839070558548'},
#                 'score': '0.99316555'},
#                {'part': 'leftWrist',
#                 'position': {'x': '66.57837319374084',
#                              'y': '342.7308769226074'},
#                 'score': '0.96176845'},
#                {'part': 'rightWrist',
#                 'position': {'x': '51.35393142700195',
#                              'y': '354.6379692554474'},
#                 'score': '0.90756816'},
#                {'part': 'leftHip',
#                 'position': {'x': '249.53378200531006',
#                              'y': '351.5149181187153'},
#                 'score': '0.9598507'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.062909603118896',
#                              'y': '359.7444095611572'},
#                 'score': '0.98424304'},
#                {'part': 'leftKnee',
#                 'position': {'x': '62.95844519138336',
#                              'y': '378.4811725616455'},
#                 'score': '0.76150674'},
#                {'part': 'rightKnee',
#                 'position': {'x': '42.55043029785156',
#                              'y': '379.28798055648804'},
#                 'score': '0.8493541'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '61.39941740036011',
#                              'y': '397.42159700393677'},
#                 'score': '0.7078566'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '41.33406639099121',
#                              'y': '443.0375633239746'},
#                 'score': '0.6738851'}],
#  'score': '0.9193176732343786'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.426010608673096',
#                              'y': '294.92212200164795'},
#                 'score': '0.9985481'},
#                {'part': 'leftEye',
#                 'position': {'x': '174.98464500904083',
#                              'y': '348.29609966278076'},
#                 'score': '0.99600476'},
#                {'part': 'rightEye',
#                 'position': {'x': '126.52229952812195',
#                              'y': '354.842622756958'},
#                 'score': '0.99948126'},
#                {'part': 'leftEar',
#                 'position': {'x': '210.35437154769897',
#                              'y': '344.2833299636841'},
#                 'score': '0.89093447'},
#                {'part': 'rightEar',
#                 'position': {'x': '22.887582778930664',
#                              'y': '292.0728759765625'},
#                 'score': '0.97787607'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.92011499404907',
#                              'y': '305.38011372089386'},
#                 'score': '0.99777204'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '222.6358540058136',
#                              'y': '304.67246186733246'},
#                 'score': '0.9992167'},
#                {'part': 'leftElbow',
#                 'position': {'x': '70.88198471069336',
#                              'y': '326.30366039276123'},
#                 'score': '0.98362607'},
#                {'part': 'rightElbow',
#                 'position': {'x': '24.488224029541016',
#                              'y': '349.7703878879547'},
#                 'score': '0.9917699'},
#                {'part': 'leftWrist',
#                 'position': {'x': '67.47726893424988',
#                              'y': '342.9812150001526'},
#                 'score': '0.9693188'},
#                {'part': 'rightWrist',
#                 'position': {'x': '51.28115653991699',
#                              'y': '355.0110831260681'},
#                 'score': '0.90460026'},
#                {'part': 'leftHip',
#                 'position': {'x': '59.233492851257324',
#                              'y': '354.712119102478'},
#                 'score': '0.95938694'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.544615030288696',
#                              'y': '359.70174503326416'},
#                 'score': '0.9869713'},
#                {'part': 'leftKnee',
#                 'position': {'x': '60.58765697479248',
#                              'y': '378.23357105255127'},
#                 'score': '0.79022014'},
#                {'part': 'rightKnee',
#                 'position': {'x': '42.146676540374756',
#                              'y': '378.6573529243469'},
#                 'score': '0.86783254'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '44.90883922576904',
#                              'y': '442.3469285964966'},
#                 'score': '0.710291'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '41.07643985748291',
#                              'y': '443.15771865844727'},
#                 'score': '0.74949795'}],
#  'score': '0.9278440194971421'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.11249923706055',
#                              'y': '295.63526916503906'},
#                 'score': '0.99864894'},
#                {'part': 'leftEye',
#                 'position': {'x': '42.66242599487305',
#                              'y': '289.7121112346649'},
#                 'score': '0.9967487'},
#                {'part': 'rightEye',
#                 'position': {'x': '136.43095016479492',
#                              'y': '350.8243246078491'},
#                 'score': '0.9987361'},
#                {'part': 'leftEar',
#                 'position': {'x': '222.7015746831894',
#                              'y': '342.74800205230713'},
#                 'score': '0.7410929'},
#                {'part': 'rightEar',
#                 'position': {'x': '23.006483554840088',
#                              'y': '292.7487392425537'},
#                 'score': '0.974614'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.930596351623535',
#                              'y': '305.13779306411743'},
#                 'score': '0.99764097'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.992040514945984',
#                              'y': '317.3128297328949'},
#                 'score': '0.9986349'},
#                {'part': 'leftElbow',
#                 'position': {'x': '64.01596546173096',
#                              'y': '325.3197946548462'},
#                 'score': '0.97966605'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.734718322753906',
#                              'y': '351.2644009590149'},
#                 'score': '0.9939932'},
#                {'part': 'leftWrist',
#                 'position': {'x': '66.83528232574463',
#                              'y': '342.1283326148987'},
#                 'score': '0.95849913'},
#                {'part': 'rightWrist',
#                 'position': {'x': '53.411906719207764',
#                              'y': '351.78673446178436'},
#                 'score': '0.9262397'},
#                {'part': 'leftHip',
#                 'position': {'x': '246.81440448760986',
#                              'y': '351.5936131477356'},
#                 'score': '0.9693717'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.46133828163147',
#                              'y': '360.3506746292114'},
#                 'score': '0.98602366'},
#                {'part': 'leftKnee',
#                 'position': {'x': '61.09292650222778',
#                              'y': '377.9116220474243'},
#                 'score': '0.7222447'},
#                {'part': 'rightKnee',
#                 'position': {'x': '44.64378476142883',
#                              'y': '378.40766859054565'},
#                 'score': '0.8543263'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '44.71416187286377',
#                              'y': '442.6986274719238'},
#                 'score': '0.69149894'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '44.657846450805664',
#                              'y': '441.9851322174072'},
#                 'score': '0.67239636'}],
#  'score': '0.9094338978038115'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.036176681518555',
#                              'y': '295.6721382141113'},
#                 'score': '0.99856335'},
#                {'part': 'leftEye',
#                 'position': {'x': '283.2110013961792',
#                              'y': '355.93246603012085'},
#                 'score': '0.997638'},
#                {'part': 'rightEye',
#                 'position': {'x': '233.73661613464355',
#                              'y': '351.80648870766163'},
#                 'score': '0.99940896'},
#                {'part': 'leftEar',
#                 'position': {'x': '314.1030025482178',
#                              'y': '352.6288112401962'},
#                 'score': '0.985743'},
#                {'part': 'rightEar',
#                 'position': {'x': '202.92155122756958',
#                              'y': '339.72358202934265'},
#                 'score': '0.9861854'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '53.81998538970947',
#                              'y': '305.6156289577484'},
#                 'score': '0.9974497'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '16.708160758018494',
#                              'y': '317.3036422729492'},
#                 'score': '0.998722'},
#                {'part': 'leftElbow',
#                 'position': {'x': '70.30532455444336',
#                              'y': '324.8702564239502'},
#                 'score': '0.98741734'},
#                {'part': 'rightElbow',
#                 'position': {'x': '24.75266933441162',
#                              'y': '350.58637738227844'},
#                 'score': '0.9919416'},
#                {'part': 'leftWrist',
#                 'position': {'x': '68.67154216766357',
#                              'y': '342.8964419364929'},
#                 'score': '0.9637686'},
#                {'part': 'rightWrist',
#                 'position': {'x': '53.69922733306885', 'y': '351.995835326612'},
#                 'score': '0.9295324'},
#                {'part': 'leftHip',
#                 'position': {'x': '54.33833122253418',
#                              'y': '355.9796841144562'},
#                 'score': '0.95990115'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.93829584121704',
#                              'y': '360.57575130462646'},
#                 'score': '0.9836902'},
#                {'part': 'leftKnee',
#                 'position': {'x': '66.26089072227478',
#                              'y': '377.0641350746155'},
#                 'score': '0.7387784'},
#                {'part': 'rightKnee',
#                 'position': {'x': '43.864673137664795',
#                              'y': '374.7980852127075'},
#                 'score': '0.8759076'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '44.13738250732422',
#                              'y': '442.5517568588257'},
#                 'score': '0.7108027'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '43.86317443847656',
#                              'y': '441.8048152923584'},
#                 'score': '0.62767154'}],
# ...
#  'score': '0.8817166738650378'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '41.56644916534424',
#                              'y': '295.6422634124756'},
#                 'score': '0.9980451'},
#                {'part': 'leftEye',
#                 'position': {'x': '211.37923407554626',
#                              'y': '335.13023710250854'},
#                 'score': '0.9972596'},
#                {'part': 'rightEye',
#                 'position': {'x': '163.1256513595581',
#                              'y': '337.82015359401703'},
#                 'score': '0.999453'},
#                {'part': 'leftEar',
#                 'position': {'x': '237.85470485687256',
#                              'y': '331.2524838447571'},
#                 'score': '0.9793467'},
#                {'part': 'rightEar',
#                 'position': {'x': '128.96012473106384',
#                              'y': '341.6528286933899'},
#                 'score': '0.9845218'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.77717208862305', 'y': '304.05549480021'},
#                 'score': '0.9972842'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '18.53005599975586',
#                              'y': '317.2141766548157'},
#                 'score': '0.99853194'},
#                {'part': 'leftElbow',
#                 'position': {'x': '68.09884929656982',
#                              'y': '327.5700225830078'},
#                 'score': '0.9793784'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.291414260864258',
#                              'y': '356.5689187049866'},
#                 'score': '0.9961365'},
#                {'part': 'leftWrist',
#                 'position': {'x': '68.51394176483154',
#                              'y': '337.9476965665817'},
#                 'score': '0.9239943'},
#                {'part': 'rightWrist',
#                 'position': {'x': '58.58716678619385',
#                              'y': '347.9890627861023'},
#                 'score': '0.89982164'},
#                {'part': 'leftHip',
#                 'position': {'x': '57.22161388397217',
#                              'y': '355.94781136512756'},
#                 'score': '0.9539041'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.826104640960693',
#                              'y': '360.9265022277832'},
#                 'score': '0.942602'},
#                {'part': 'leftKnee',
#                 'position': {'x': '70.12084102630615',
#                              'y': '375.5981149673462'},
#                 'score': '0.4919131'},
#                {'part': 'rightKnee',
#                 'position': {'x': '47.68285045027733',
#                              'y': '374.80286502838135'},
#                 'score': '0.851296'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '40.73878765106201',
#                              'y': '441.2589740753174'},
#                 'score': '0.44755664'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '42.62129497528076', 'y': '424.964656829834'},
#                 'score': '0.64353675'}],
#  'score': '0.8873283372205847'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '41.02278518676758',
#                              'y': '296.22279834747314'},
#                 'score': '0.99795735'},
#                {'part': 'leftEye',
#                 'position': {'x': '193.39268040657043',
#                              'y': '361.8199405670166'},
#                 'score': '0.99786216'},
#                {'part': 'rightEye',
#                 'position': {'x': '142.74256539344788',
#                              'y': '368.48954659700394'},
#                 'score': '0.9993104'},
#                {'part': 'leftEar',
#                 'position': {'x': '230.3587703704834',
#                              'y': '334.4942184686661'},
#                 'score': '0.9876386'},
#                {'part': 'rightEar',
#                 'position': {'x': '25.01763153076172',
#                              'y': '293.0731735229492'},
#                 'score': '0.95537454'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.206997871398926',
#                              'y': '305.1095962524414'},
#                 'score': '0.9977592'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '18.448219776153564',
#                              'y': '317.0086236000061'},
#                 'score': '0.9986754'},
#                {'part': 'leftElbow',
#                 'position': {'x': '71.77315425872803',
#                              'y': '331.5659852027893'},
#                 'score': '0.98031473'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.032886505126953',
#                              'y': '355.77431774139404'},
#                 'score': '0.9959985'},
#                {'part': 'leftWrist',
#                 'position': {'x': '68.26797103881836',
#                              'y': '338.5396511554718'},
#                 'score': '0.9343187'},
#                {'part': 'rightWrist',
#                 'position': {'x': '58.26838684082031',
#                              'y': '348.3942768573761'},
#                 'score': '0.900486'},
#                {'part': 'leftHip',
#                 'position': {'x': '57.31168794631958',
#                              'y': '354.9702935218811'},
#                 'score': '0.9593041'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.64662504196167',
#                              'y': '360.22722148895264'},
#                 'score': '0.95295334'},
#                {'part': 'leftKnee',
#                 'position': {'x': '66.73753499984741',
#                              'y': '371.48448944091797'},
#                 'score': '0.41577676'},
#                {'part': 'rightKnee',
#                 'position': {'x': '46.227293491363525',
#                              'y': '371.041522026062'},
#                 'score': '0.8107209'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '63.58101823925972',
#                              'y': '394.83697509765625'},
#                 'score': '0.44861832'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '43.2956485748291', 'y': '422.8644609451294'},
#                 'score': '0.6158471'}],
#  'score': '0.879348008071675'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '41.19019079208374',
#                              'y': '295.8510398864746'},
#                 'score': '0.9980388'},
#                {'part': 'leftEye',
#                 'position': {'x': '183.48211145401', 'y': '363.45571422576904'},
#                 'score': '0.99772626'},
#                {'part': 'rightEye',
#                 'position': {'x': '129.98920238018036',
#                              'y': '368.54955810308456'},
#                 'score': '0.9991321'},
#                {'part': 'leftEar',
#                 'position': {'x': '219.09755563735962',
#                              'y': '342.3803014755249'},
#                 'score': '0.9697169'},
#                {'part': 'rightEar',
#                 'position': {'x': '25.405755519866943',
#                              'y': '293.6054859161377'},
#                 'score': '0.9540481'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.89858055114746',
#                              'y': '304.66659593582153'},
#                 'score': '0.9982711'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '17.998587489128113',
#                              'y': '317.17708802223206'},
#                 'score': '0.9986792'},
#                {'part': 'leftElbow',
#                 'position': {'x': '71.99314403533936',
#                              'y': '328.6602234840393'},
#                 'score': '0.98072284'},
#                {'part': 'rightElbow',
#                 'position': {'x': '23.83638095855713',
#                              'y': '355.85683035850525'},
#                 'score': '0.9950472'},
#                {'part': 'leftWrist',
#                 'position': {'x': '67.19606637954712',
#                              'y': '338.10343837738037'},
#                 'score': '0.9447064'},
#                {'part': 'rightWrist',
#                 'position': {'x': '56.73006534576416',
#                              'y': '348.3759911060333'},
#                 'score': '0.9109026'},
#                {'part': 'leftHip',
#                 'position': {'x': '57.049521923065186',
#                              'y': '355.4906244277954'},
#                 'score': '0.9509056'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.392776012420654',
#                              'y': '360.5480875968933'},
#                 'score': '0.94849455'},
#                {'part': 'leftKnee',
#                 'position': {'x': '65.72215068340302',
#                              'y': '372.53257274627686'},
#                 'score': '0.46618968'},
#                {'part': 'rightKnee',
#                 'position': {'x': '46.700753569602966',
#                              'y': '371.4326705932617'},
#                 'score': '0.80998516'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '41.29280185699463',
#                              'y': '439.25244331359863'},
#                 'score': '0.42988354'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '43.06500053405762',
#                              'y': '424.0780429840088'},
#                 'score': '0.568145'}],
#  'score': '0.877682065262514'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '43.48133182525635',
#                              'y': '296.6340923309326'},
#                 'score': '0.99764'},
#                {'part': 'leftEye',
#                 'position': {'x': '187.306866645813',
#                              'y': '364.99550557136536'},
#                 'score': '0.9977284'},
#                {'part': 'rightEye',
#                 'position': {'x': '135.6438946723938',
#                              'y': '369.35983538627625'},
#                 'score': '0.9987576'},
#                {'part': 'leftEar',
#                 'position': {'x': '224.99496746063232',
#                              'y': '342.8424415588379'},
#                 'score': '0.96766794'},
#                {'part': 'rightEar',
#                 'position': {'x': '25.540587425231934',
#                              'y': '294.29255390167236'},
#                 'score': '0.9605392'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '55.27676486968994',
#                              'y': '305.1019856929779'},
#                 'score': '0.9980236'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '18.671815156936646',
#                              'y': '317.2676157951355'},
#                 'score': '0.9986437'},
#                {'part': 'leftElbow',
#                 'position': {'x': '72.07105016708374',
#                              'y': '331.68530797958374'},
#                 'score': '0.9813301'},
#                {'part': 'rightElbow',
#                 'position': {'x': '24.865612030029297',
#                              'y': '355.8058078289032'},
#                 'score': '0.99598145'},
#                {'part': 'leftWrist',
#                 'position': {'x': '65.83639705181122',
#                              'y': '337.4525521993637'},
#                 'score': '0.9468517'},
#                {'part': 'rightWrist',
#                 'position': {'x': '57.31876564025879',
#                              'y': '347.49749279022217'},
#                 'score': '0.916068'},
#                {'part': 'leftHip',
#                 'position': {'x': '58.209983825683594',
#                              'y': '354.51095151901245'},
#                 'score': '0.9609462'},
#                {'part': 'rightHip',
#                 'position': {'x': '28.709802865982056',
#                              'y': '360.14377880096436'},
#                 'score': '0.9447785'},
#                {'part': 'leftKnee',
#                 'position': {'x': '66.92367887496948',
#                              'y': '371.8882761001587'},
#                 'score': '0.48692447'},
#                {'part': 'rightKnee',
#                 'position': {'x': '46.51261579990387',
#                              'y': '370.5279369354248'},
#                 'score': '0.78767115'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '64.49080467224121',
#                              'y': '395.7255721092224'},
#                 'score': '0.44838265'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '43.5261173248291', 'y': '423.4540400505066'},
#                 'score': '0.6179325'}],
#  'score': '0.8826980713535758'}
# {'keypoints': [{'part': 'nose',
#                 'position': {'x': '40.76916742324829',
#                              'y': '295.8355960845947'},
#                 'score': '0.99832934'},
#                {'part': 'leftEye',
#                 'position': {'x': '187.20281171798706',
#                              'y': '362.98646354675293'},
#                 'score': '0.9976178'},
#                {'part': 'rightEye',
#                 'position': {'x': '35.77398324012756',
#                              'y': '291.8254578113556'},
#                 'score': '0.9987594'},
#                {'part': 'leftEar',
#                 'position': {'x': '225.91126239299774',
#                              'y': '341.9078960418701'},
#                 'score': '0.97384757'},
#                {'part': 'rightEar',
#                 'position': {'x': '24.687722206115723',
#                              'y': '293.0007472038269'},
#                 'score': '0.9526527'},
#                {'part': 'leftShoulder',
#                 'position': {'x': '54.99906253814697',
#                              'y': '304.71276319026947'},
#                 'score': '0.99822193'},
#                {'part': 'rightShoulder',
#                 'position': {'x': '18.746286392211914',
#                              'y': '317.20873832702637'},
#                 'score': '0.9985607'},
#                {'part': 'leftElbow',
#                 'position': {'x': '71.77717590332031',
#                              'y': '330.8445601463318'},
#                 'score': '0.9725028'},
#                {'part': 'rightElbow',
#                 'position': {'x': '25.829988479614258',
#                              'y': '355.2720191478729'},
#                 'score': '0.9955295'},
#                {'part': 'leftWrist',
#                 'position': {'x': '67.11759209632874',
#                              'y': '338.07427191734314'},
#                 'score': '0.9408702'},
#                {'part': 'rightWrist',
#                 'position': {'x': '58.05778884887695',
#                              'y': '348.2052195072174'},
#                 'score': '0.90910894'},
#                {'part': 'leftHip',
#                 'position': {'x': '57.73036813735962',
#                              'y': '354.85452008247375'},
#                 'score': '0.948177'},
#                {'part': 'rightHip',
#                 'position': {'x': '29.679006099700928',
#                              'y': '361.4167995452881'},
#                 'score': '0.95020753'},
#                {'part': 'leftKnee',
#                 'position': {'x': '68.0325813293457',
#                              'y': '371.16797256469727'},
#                 'score': '0.43296257'},
#                {'part': 'rightKnee',
#                 'position': {'x': '20.146223068237305',
#                              'y': '366.1663455963135'},
#                 'score': '0.7527875'},
#                {'part': 'leftAnkle',
#                 'position': {'x': '63.58042371273041',
#                              'y': '395.08552598953247'},
#                 'score': '0.48304063'},
#                {'part': 'rightAnkle',
#                 'position': {'x': '41.532498359680176',
#                              'y': '421.1194977760315'},
#                 'score': '0.54638433'}],
#  'score': '0.8735035535167245'}

# %%
p.record()

# %%
p.play(plt.axes(), None)

# %%
p.stop_posenet()

# %%
p.start_posenet()

# %%
r.save("opera")

# %%
r = load_recorder(shimi, "bow")

# %%
r.append_recording(load_recorder(shimi, "bow"))

# %%
r.append_recording(r2)

# %%
PlaySongDemoOnce(shimi)

# %%
f, (pos_ax, vel_ax) = plt.subplots(2, 1)
playback(shimi, [1], 3.5, [0.0, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0, 3.5], [[0.5], [0.5], [0.5], [0.5], [0.8], [0.1], [0.2], [0.5]], np.array([]), pos_ax=pos_ax, vel_ax=vel_ax)

# %%
test_pm = pm.PrettyMIDI('audio/test.mid')

# %%
out = test_pm.synthesize()

# %%
import sounddevice as sd
import music21 as m21
import pretty_midi as pm

# %%
sd.play(out, 44100)

# %%
f = m21.midi.MidiFile()
f.open('audio/test.mid')
f.read()
s = m21.midi.translate.midiFileToStream(f)

# %%
for i in s.melodicIntervals(skipRests=True):
    print(i)

# %%
s.pitches
